# %%
import mlflow

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor

mlflow.set_experiment("diabetes_rf_experiment")

# Enable MLflow's automatic experiment tracking for scikit-learn
mlflow.sklearn.autolog()

# Load the training dataset
db = load_diabetes()
X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
# MLflow triggers logging automatically upon model fitting
rf.fit(X_train, y_train)
# Out:
# 2025/05/23 03:22:38 INFO mlflow.tracking.fluent: Experiment with name 'diabetes_rf_experiment' does not exist. Creating a new experiment.
# 2025/05/23 03:22:40 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'a1wd-7amf-vusl-ttxa', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# RandomForestRegressor(max_depth=6, max_features=3)

# %%
# !pip install mlflow scikit-learn
# Out:
# Collecting mlflow
#   Downloading mlflow-2.22.0-py3-none-any.whl.metadata (30 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting mlflow-skinny==2.22.0 (from mlflow)
#   Downloading mlflow_skinny-2.22.0-py3-none-any.whl.metadata (31 kB)
# Collecting Flask<4 (from mlflow)
#   Downloading flask-3.1.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.10/site-packages (from mlflow) (3.1.5)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.16.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting markdown<4,>=3.3 (from mlflow)
#   Downloading markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.10/site-packages (from mlflow) (3.7.0)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.10/site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: pandas<3 in /usr/local/lib/python3.10/site-packages (from mlflow) (2.1.4)
# Collecting pyarrow<20,>=4.0.0 (from mlflow)
#   Downloading pyarrow-19.0.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting scipy<2 (from mlflow)
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.10/site-packages (from mlflow) (2.0.24)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /runtime-addons/cmladdon-2.0.47-b365/opt/cmladdons/python/site-packages (from mlflow-skinny==2.22.0->mlflow) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (3.0.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /runtime-addons/cmladdon-2.0.47-b365/opt/cmladdons/python/site-packages (from mlflow-skinny==2.22.0->mlflow) (0.39.0)
# Collecting fastapi<1 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (3.1.41)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /usr/local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (7.1.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /runtime-addons/cmladdon-2.0.47-b365/opt/cmladdons/python/site-packages (from mlflow-skinny==2.22.0->mlflow) (1.29.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /runtime-addons/cmladdon-2.0.47-b365/opt/cmladdons/python/site-packages (from mlflow-skinny==2.22.0->mlflow) (1.29.0)
# Requirement already satisfied: packaging<25 in /usr/local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (23.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /usr/local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (4.25.3)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /usr/local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (2.4.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (6.0)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /runtime-addons/cmladdon-2.0.47-b365/opt/cmladdons/python/site-packages (from mlflow-skinny==2.22.0->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /usr/local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (4.12.2)
# Collecting uvicorn<1 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (2.0.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow) (2.2.2)
# Collecting blinker>=1.9.0 (from Flask<4->mlflow)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.10/site-packages (from Flask<4->mlflow) (2.1.2)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /usr/local/lib/python3.10/site-packages (from graphene<4->mlflow) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/site-packages (from pandas<3->mlflow) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/site-packages (from pandas<3->mlflow) (2023.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.3)
# Requirement already satisfied: google-auth~=2.0 in /runtime-addons/cmladdon-2.0.47-b365/opt/cmladdons/python/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (2.37.0)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi<1->mlflow-skinny==2.22.0->mlflow)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.22.0->mlflow) (3.18.1)
# Requirement already satisfied: deprecated>=1.2.6 in /runtime-addons/cmladdon-2.0.47-b365/opt/cmladdons/python/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (1.2.15)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in /runtime-addons/cmladdon-2.0.47-b365/opt/cmladdons/python/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (0.50b0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.10.0 in /usr/local/lib/python3.10/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (2.10.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (2024.7.4)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/site-packages (from uvicorn<1->mlflow-skinny==2.22.0->mlflow) (0.14.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /runtime-addons/cmladdon-2.0.47-b365/opt/cmladdons/python/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (1.17.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /runtime-addons/cmladdon-2.0.47-b365/opt/cmladdons/python/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /runtime-addons/cmladdon-2.0.47-b365/opt/cmladdons/python/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (4.9)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.10/site-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (4.7.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /runtime-addons/cmladdon-2.0.47-b365/opt/cmladdons/python/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (0.6.1)
# Downloading mlflow-2.22.0-py3-none-any.whl (29.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 71.8 MB/s eta 0:00:00:00:01
# Downloading mlflow_skinny-2.22.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 35.9 MB/s eta 0:00:00
# Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 48.4 MB/s eta 0:00:00:00:01
# Downloading alembic-1.16.1-py3-none-any.whl (242 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading flask-3.1.1-py3-none-any.whl (103 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading joblib-1.5.0-py3-none-any.whl (307 kB)
# Downloading markdown-3.8-py3-none-any.whl (106 kB)
# Downloading pyarrow-19.0.1-cp310-cp310-manylinux_2_28_x86_64.whl (42.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 85.8 MB/s eta 0:00:00:00:0100:01
# Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 67.0 MB/s eta 0:00:00:00:0100:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
# Installing collected packages: werkzeug, uvicorn, threadpoolctl, scipy, pyarrow, markdown, Mako, joblib, itsdangerous, gunicorn, graphql-core, blinker, starlette, scikit-learn, graphql-relay, Flask, docker, alembic, graphene, fastapi, mlflow-skinny, mlflow
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlflow-cml-plugin 0.0.1 requires mlflow-skinny==2.19.0, but you have mlflow-skinny 2.22.0 which is incompatible.
# mlflow-cml-plugin 0.0.1 requires typing-extensions==4.10.0, but you have typing-extensions 4.12.2 which is incompatible.
# Successfully installed Flask-3.1.1 Mako-1.3.10 alembic-1.16.1 blinker-1.9.0 docker-7.1.0 fastapi-0.115.12 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 gunicorn-23.0.0 itsdangerous-2.2.0 joblib-1.5.0 markdown-3.8 mlflow-2.22.0 mlflow-skinny-2.22.0 pyarrow-19.0.1 scikit-learn-1.6.1 scipy-1.15.3 starlette-0.46.2 threadpoolctl-3.6.0 uvicorn-0.34.2 werkzeug-3.1.3
